# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tmdb-movies-dataset-2023-930k-movies/TMDB_movie_dataset_v11.csv

# %%
data = pd.read_csv("/kaggle/input/tmdb-movies-dataset-2023-930k-movies/TMDB_movie_dataset_v11.csv")
print(data.columns)
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
black_panther = data[data["title"] == "Black Panther"]
print(black_panther)
# Out:
#              id          title  vote_average  vote_count    status  \
# 27       284054  Black Panther          7.39       21053  Released
# 46013     86841  Black Panther          5.80          23  Released
# 75760    299096  Black Panther          6.00          10  Released
# 537969  1186236  Black Panther          0.00           0  Released
#
#        release_date     revenue  runtime  adult  \
# 27       2018-02-13  1349926083      135  False
# 46013    2010-01-18           0      120  False
# 75760    2013-06-30           0       77  False
# 537969   1993-01-01           0        0  False
#
#                            backdrop_path  ...     original_title  \
# 27      /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg  ...      Black Panther
# 46013   /qm2hWnMkj9jPjGlAHaHRj7FDeJb.jpg  ...      Black Panther
# 75760   /hfmJG3EE7l1BJuUikKWusHb4Fb8.jpg  ...  Schwarzer Panther
# 537969                               NaN  ...                 黑豹
#
#                                                  overview popularity  \
# 27      King T'Challa returns home to the reclusive, t...     43.665
# 46013   Black Panther is the ruler and protector of th...      3.069
# 75760   After many years apart, Emilie meets her broth...      1.663
# 537969                                    Hong Kong movie      0.600
#
#                              poster_path              tagline  \
# 27      /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  Long live the king.
# 46013   /aXmsbVlvLCuBDMxUvpDJdYSAOFQ.jpg                  NaN
# 75760   /z5gMdlXTZmmBt2mYtFn4i4Pi9uH.jpg                  NaN
# 537969                               NaN                  NaN
#
#                                     genres  \
# 27      Action, Adventure, Science Fiction
# 46013                            Animation
# 75760                                Drama
# 537969                                 NaN
#
#                                      production_companies  \
# 27                                         Marvel Studios
# 46013                                      Marvel Knights
# 75760   Deutsche Film- und Fernsehakademie Berlin (DFF...
# 537969                                                NaN
#
#             production_countries                 spoken_languages  \
# 27      United States of America  English, Korean, Swahili, Xhosa
# 46013                        NaN                          English
# 75760                    Germany          English, French, German
# 537969                       NaN                              NaN
#
#                                                  keywords
# 27      africa, superhero, based on comic, aftercredit...
# 46013                           superhero, based on comic
# 75760   sibling relationship, forbidden love, family s...
# 537969                                                NaN
#
# [4 rows x 24 columns]
